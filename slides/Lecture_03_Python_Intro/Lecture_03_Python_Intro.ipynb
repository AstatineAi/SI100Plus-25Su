# %% [markdown]
# ## Lecture 2: 编程语言和Python简介
#
# *100% 真人手敲制作！不含任何 GPT 成分！*
#
# Made with ♥ by SI100+ (2025) Staff.

# %% [markdown]
# ### Python 基础语义 - 执行顺序
#
# 运行下面的代码，看看输出结果是什么？

# %%
x = 123
y = 456
print(x + y)
print("Hello, SI100+ 2025!")

# %% [markdown]
# 可以发现，先输出了 $123 + 456$ 的结果 $579$，然后输出了 Hello, SI100+ 2025!
#
# 试着调换一下两个含有 `print` 的行：

# %%
x = 123
y = 456
print("Hello, SI100+ 2025!")
print(x + y)

# %% [markdown]
# 运行后发现，输出结果变成了 Hello, SI100+ 2025! 和 579，与之前的输出结果不同。
#
# Python 的执行顺序就是这样，从上到下，逐行执行。
#
# 如果我们再调换一些代码的位置？

# %%
p = 123
print(p + q)
q = 456
print("Hello, SI100+ 2025!")

# %% [markdown]
# 代码运行出现了错误，因为从上到下执行，在执行 `print(p + q)` 时，还没有执行 `q = 456`，我们并没有得到这个 `q`，不能在 `print(p + q)` 中使用它。

# %% [markdown]
# ### Python 基础语义 - `print` 语句
#
# 尝试运行下面的代码，看看会发生什么。

# %%
print("Hello, SI100+ 2025!")

# %%
print("Hello, ShanghaiTech!")

# %% [markdown]
# 总结“规律”：
#
# 1. 两个 `print` 都输出了一行内容
# 2. 两个 `print` 输出的内容和后面括号内的内容一致
#
# 即，`print` 的含义是“输出括号内的内容”。
#
# 举一反三，提取这个语法的结构：
#
# > 前面的内容 左括号( 中间的内容 )右括号
#
# 前面，我们尝试替换了 `print` 后括号内的内容，但是依然局限于一些句子，如果替换成别的东西呢？

# %%
# 我们可不可以输出 print 本身
print(print)

# %%
# 还能输出什么，试一试
print(    )

# %% [markdown]
# `print(print)` 得到了结果：`<built-in function print>`，也就是 `print` 确实把括号内的内容输出了，`print` 的含义就是一个内置的（built-in）函数。

# %% [markdown]
# ### Python 基础语义 - 形如 `x = y` 的语句
#
# 我们用前面发现的 `print` 语句，来看看执行 `x = y` 起到了什么作用。

# %%
x = 123
print(x)

x = 456
print(x)

# %% [markdown]
# ### Python 基础语义 - 数学表达式
#
# 我们会在 “变量、运算符、表达式” 一节中详细讲述我们可以进行哪些数学运算。

# %%
x = 123 * 456 + 789
print(x)

# %% [markdown]
# ### Python 基础语义 - 组合语句
#
# 我们可以把上面的要素结合在一起。

# %%
x = 123
y = 3 * x ** 2 + 2 * x + 1
z = x * y - (x + y) ** 2
print(y)
print(z)

# %% [markdown]
# # 小练习
#
# 下面是我们课堂上演示的程序和代码，你能
#
# - 根据流程图/结合大语言模型的帮助猜出每行代码的含义吗？
# - 尝试将 `!=` 修改成 `<=` 结果有什么变化？你能猜出 `!=` 的含义吗？
#
# ![image-3.png](attachment:image-3.png)

# %%
import random

x = random.randint(1, 100)
guess = int(input())
while guess != x:
    print("Try again!")
    guess = int(input())
print("Congratulations!")
